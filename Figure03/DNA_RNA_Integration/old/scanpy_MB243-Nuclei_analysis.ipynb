# %% [markdown]
# # NOTEBOOK FOR THE ANALYSIS OF SINGLE-NUCLEI RNA-SEQUENCING DATA FROM MB243

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import bbknn
import scrublet as scr

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white')

# %%
results_file = '/icgc/dkfzlsdf/analysis/B260/projects/przybilm/medulloblastoma/scRNA_analysis/scanpy/MB243-Nuclei_scanpy.h5ad'  # the file that will store the analysis results

# %% [markdown]
# ## READ IN THE DATA FOR MB243-NUCLEI AND PERFORM DOUBLET REMOVAL WITH SCRUBLET

# %%
adata = sc.read_10x_mtx(
    '/icgc/dkfzlsdf/analysis/B260/projects/chromothripsis_medulloblastoma/data/10XRNA5P/MB243/MB243-Nuclei/outs/filtered_feature_bc_matrix/',  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)                              # write a cache file for faster subsequent reading

adata.var_names_make_unique()
adata

# make some metadata
adata.obs['sample'] = "MB243"
adata.obs['technology'] = "Nuclei"
adata.obs['patient'] = "MB243"
# Out:
# ... reading from cache file cache/icgc-dkfzlsdf-analysis-B260-projects-chromothripsis_medulloblastoma-data-10XRNA5P-MB243-MB243-Nuclei-outs-filtered_feature_bc_matrix-matrix.h5ad
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
adata.obs
# Out:
#                    sample technology patient
# AAACCTGAGAAACCGC-1  MB243     Nuclei   MB243
# AAACCTGAGAACAATC-1  MB243     Nuclei   MB243
# AAACCTGAGCACCGTC-1  MB243     Nuclei   MB243
# AAACCTGAGCAGCGTA-1  MB243     Nuclei   MB243
# AAACCTGAGGAATTAC-1  MB243     Nuclei   MB243
# ...                   ...        ...     ...
# TTTGTCATCAATCACG-1  MB243     Nuclei   MB243
# TTTGTCATCACCATAG-1  MB243     Nuclei   MB243
# TTTGTCATCCCAACGG-1  MB243     Nuclei   MB243
# TTTGTCATCGCTTGTC-1  MB243     Nuclei   MB243
# TTTGTCATCTATGTGG-1  MB243     Nuclei   MB243
#
# [7724 rows x 3 columns]

# %%
scrub = scr.Scrublet(
        counts_matrix=adata.X,
        expected_doublet_rate=0.06,  # Default is 0.1
        random_state=0)

# %%
doublet_scores, predicted_doublets = scrub.scrub_doublets(min_counts=2, 
                                                          min_cells=3, 
                                                          min_gene_variability_pctl=85, 
                                                          n_prin_comps=30)
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 6.0%
# 	Estimated  = 0.0%
# Elapsed time: 19.8 seconds

# %%
scrub.plot_histogram();

# %%
adata.obs['scrublet__predicted_multiplet'] = scrub.predicted_doublets_
adata.obs['scrublet__multiplet_scores'] = scrub.doublet_scores_obs_
adata.obs['scrublet__multiplet_zscores'] = scrub.z_scores_

# %%
adata.obs
# Out:
#                    sample technology patient  scrublet__predicted_multiplet  \
# AAACCTGAGAAACCGC-1  MB243     Nuclei   MB243                          False
# AAACCTGAGAACAATC-1  MB243     Nuclei   MB243                          False
# AAACCTGAGCACCGTC-1  MB243     Nuclei   MB243                          False
# AAACCTGAGCAGCGTA-1  MB243     Nuclei   MB243                          False
# AAACCTGAGGAATTAC-1  MB243     Nuclei   MB243                          False
# ...                   ...        ...     ...                            ...
# TTTGTCATCAATCACG-1  MB243     Nuclei   MB243                          False
# TTTGTCATCACCATAG-1  MB243     Nuclei   MB243                          False
# TTTGTCATCCCAACGG-1  MB243     Nuclei   MB243                          False
# TTTGTCATCGCTTGTC-1  MB243     Nuclei   MB243                          False
# TTTGTCATCTATGTGG-1  MB243     Nuclei   MB243                          False
#
#                     scrublet__multiplet_scores  scrublet__multiplet_zscores
# AAACCTGAGAAACCGC-1                    0.067505                   -14.449359
# AAACCTGAGAACAATC-1                    0.139767                    -5.734176
# AAACCTGAGCACCGTC-1                    0.085812                   -10.869718
# AAACCTGAGCAGCGTA-1                    0.042561                   -24.184220
# AAACCTGAGGAATTAC-1                    0.202037                    -3.188116
# ...                                        ...                          ...
# TTTGTCATCAATCACG-1                    0.054088                   -18.586933
# TTTGTCATCACCATAG-1                    0.127610                    -6.516074
# TTTGTCATCCCAACGG-1                    0.139767                    -5.734176
# TTTGTCATCGCTTGTC-1                    0.107797                    -8.163410
# TTTGTCATCTATGTGG-1                    0.032769                   -31.956221
#
# [7724 rows x 6 columns]

# %%
# remove predicted doublets
adata = adata[adata.obs['scrublet__predicted_multiplet'] == False]
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %% [markdown]
# ## START PERFORMING THE INITIAL QUALITY CONTROL

# %%
# preprocessing
sc.pl.highest_expr_genes(adata, n_top=20,)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# normalizing counts per cell
#     finished (0:00:00)

# %%
# basic filtering
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# filtered out 9006 genes that are detected in less than 3 cells

# %%
# calculate some quality metrics as for instance mitochondrial percentage
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# and for ribosomal genes
adata.var['ribo'] = adata.var_names.str.startswith(('RPS','RPL'))  # annotate the group of ribosomal genes as 'ribo'
sc.pp.calculate_qc_metrics(adata, qc_vars=['ribo'], percent_top=None, log1p=False, inplace=True)

# %%
# visualize some QC metrics
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],
             jitter=0.4, multi_panel=True)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'sample' as categorical
# ... storing 'technology' as categorical
# ... storing 'patient' as categorical
# ... storing 'feature_types' as categorical

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
# do the actual filtering by slicing the object
adata = adata[300 < adata.obs.n_genes_by_counts, :]
adata = adata[adata.obs.n_genes_by_counts < 6000, :]
adata = adata[500 < adata.obs.total_counts, :]
adata = adata[adata.obs.total_counts < 25000, :]
adata = adata[adata.obs.pct_counts_mt < 5, :]
adata = adata[adata.obs.pct_counts_ribo < 10, :]
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2630: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 7302 × 23732
#     obs: 'sample', 'technology', 'patient', 'scrublet__predicted_multiplet', 'scrublet__multiplet_scores', 'scrublet__multiplet_zscores', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'ribo'

# %%
# calculate mean number of genes detected
mean_genes = adata.obs['n_genes'].mean()
print(mean_genes)

# calculate mean number of transcripts detected
mean_counts = adata.obs['total_counts'].mean()
print(mean_counts)
# Out:
# 2256.308545603944
# 4037.484619140625

# %% [markdown]
# ## PERFORM NORMALIZATION, PCA AND CLUSTERING

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# normalizing counts per cell
#     finished (0:00:00)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# Out:
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(adata)

# %%
# set the raw attribute of anndata
adata.raw = adata

# %%
adata = adata[:, adata.var.highly_variable]

# %%
# regress out effects of total counts per cell and the percentage of mitochondrial genes
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt', 'pct_counts_ribo'])
# Out:
# regressing out ['total_counts', 'pct_counts_mt', 'pct_counts_ribo']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:31)

# %%
sc.pp.scale(adata, max_value=10)
sc.tl.pca(adata, svd_solver='arpack')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:06)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
adata.write(results_file)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7302 × 3339
#     obs: 'sample', 'technology', 'patient', 'scrublet__predicted_multiplet', 'scrublet__multiplet_scores', 'scrublet__multiplet_zscores', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
# compute nearest neighbors, UMAP and clustering
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=8)
sc.tl.umap(adata, n_components=2, min_dist=0.1,  # Scanpy default = 0.05
           spread=1.0, copy=False, random_state=0)
sc.tl.louvain(adata, resolution= 0.4)
sc.tl.leiden(adata, resolution= 0.2)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 8
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:04)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:14)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 8 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(adata, color=['leiden', 'louvain'], save = '_MB243-Nuclei.pdf', wspace = 0.4)
# Out:
# WARNING: saving figure to file figures/umap_MB243-Nuclei.pdf
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
adata.write(results_file)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
# find marker genes for each cluster using the Wilcoxon rank sum test
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False, save = "_MB243-Nuclei_leiden.pdf")
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:19)
# WARNING: saving figure to file figures/rank_genes_groups_leiden_MB243-Nuclei_leiden.pdf

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
wilcoxon_df = pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', "scores", 'logfoldchanges', "pvals", 'pvals_adj']})

# %%
wilcoxon_df.to_csv("/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/scanpy/MB243_DEG_wilcoxon.csv")

# %%
wilcoxon_df
# Out:
#           0_n        0_s       0_l            0_p     1_n        1_s  \
# 0        GLI2  31.037891  1.057537  3.944455e-207  MARCH1  47.476772
# 1      ZNF536  24.568985  0.672876  2.144715e-129  DLGAP1  43.769634
# 2       DSCAM  22.298138  0.527286  1.828329e-106   PLCL1  42.902317
# 3      HIVEP3  21.214748  0.724664   2.760818e-96   NCAM2  42.709518
# 4       PRKCB  20.766165  1.341364   2.969174e-92  PDZRN4  42.327454
# ...       ...        ...       ...            ...     ...        ...
# 23727   DOCK4 -18.283674 -0.979987   2.208000e-71    CDK6 -27.964590
# 23728  CCSER1 -19.586481 -0.573490   5.317339e-82   PTCH1 -28.191572
# 23729   NCAM2 -19.808687 -1.291638   7.432150e-84  POU6F2 -28.524588
# 23730   PLCL1 -23.290657 -1.511638  3.271048e-116   LAMA2 -28.579350
# 23731  MARCH1 -25.928272 -1.367287  3.793956e-144  HIVEP3 -31.862295
#
#             1_l            1_p        2_n        2_s  ...       5_l  \
# 0      2.635506   0.000000e+00      NTRK3  29.796991  ...  1.812973
# 1      2.521353   0.000000e+00       GAB1  28.869959  ...  2.696561
# 2      2.882963   0.000000e+00      NDST3  27.013849  ...  4.685343
# 3      2.873315   0.000000e+00     CSNK1E  26.954912  ...  3.405818
# 4      3.850083   0.000000e+00      DACH2  25.867548  ...  3.488355
# ...         ...            ...        ...        ...  ...       ...
# 23727 -1.044497  2.810587e-169     PLXDC2 -16.816824  ... -1.077411
# 23728 -1.865971  4.890366e-172     CLASP1 -17.480717  ... -1.289445
# 23729 -1.204661  3.936862e-176  LINC00478 -18.511482  ... -1.486778
# 23730 -1.159864  8.469744e-177      CNTN3 -18.767065  ... -1.249908
# 23731 -1.400781  9.177074e-220       NRG3 -19.063869  ... -1.120445
#
#                 5_p           6_n        6_s       6_l           6_p      7_n  \
# 0      9.116808e-51         RBMS3  18.061289  5.171237  1.526031e-68    MYRIP
# 1      4.424627e-50          DLC1  17.328661  8.388729  3.392612e-63  GALNT18
# 2      7.230112e-44        MALAT1  16.972395  1.057525  1.039946e-60     FLI1
# 3      1.432216e-43  CTD-3179P9.1  16.809828  8.720617  1.226759e-59      VWF
# 4      1.040808e-41          RORA  16.704172  3.051138  5.800707e-59    MECOM
# ...             ...           ...        ...       ...           ...      ...
# 23727  8.239095e-30          GLI2 -13.123561 -2.056474  1.847457e-36      FTX
# 23728  1.110141e-30          NFIB -13.210465 -1.071155  6.039878e-37   CTNNA2
# 23729  3.888934e-32       TMEM108 -13.558252 -1.662573  6.001079e-39   CASC15
# 23730  3.704640e-35         GPM6A -14.040103 -1.941179  9.555723e-42  TMEM108
# 23731  1.375972e-42         SEZ6L -15.357196 -2.213958  6.838945e-50    SEZ6L
#
#             7_s       7_l           7_p
# 0      9.542668  5.563497  3.303568e-17
# 1      9.347411  7.051294  9.793082e-17
# 2      9.313407  7.452648  9.793082e-17
# 3      9.163856  9.810876  2.970988e-16
# 4      9.120922  5.489264  3.016690e-16
# ...         ...       ...           ...
# 23727 -5.927285 -0.769515  8.305798e-07
# 23728 -5.990930 -1.785241  5.894711e-07
# 23729 -6.367419 -1.593889  6.709006e-08
# 23730 -6.420586 -1.676425  4.808409e-08
# 23731 -7.297349 -1.808271  1.882474e-10
#
# [23732 rows x 32 columns]

# %%
new_cluster_names = ['cluster0', 'cluster1', 'cluster2', 'cluster3', 'cluster4', 'cluster5', 'cluster6', 'cluster7']
adata.rename_categories('leiden', new_cluster_names)

old_to_new = dict(
    cluster0='malignant basal state',
    cluster1='malignant neuronal development',
    cluster2='malignant SHH',
    cluster3='malignant cycling',
    cluster4='macrophages',
    cluster5='astrocytes',
    cluster6='meninge cells',
    cluster7='endothelial cells',
)

adata.obs['new_clusters'] = (
    adata.obs['leiden']
    .map(old_to_new)
    .astype('category')
)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2630: FutureWarning: The `inplace` parameter in pandas.Categorical.rename_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %%
sc.pl.umap(adata, color=['new_clusters'], save = '_MB243-Nuclei_CellType.pdf', wspace = 0.6, legend_fontsize = 6)
# Out:
# WARNING: saving figure to file figures/umap_MB243-Nuclei_CellType.pdf

# %%
adata.write("/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/scanpy/MB243-Nuclei_Aurelie_Celltype_scanpy.h5ad")

# %%
metadata = pd.DataFrame(adata.obs, index=adata.obs_names)
metadata.to_csv('/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/scanpy/MB243-Nuclei_metadata.csv')

# %% [markdown]
# ## PROJECT THE ALIGNED SCDNA-CLONES ON THE EMBEDDING

# %%
adata = sc.read("/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/scanpy/MB243-Nuclei_Aurelie_Celltype_scanpy.h5ad")

# %%
scDNA_clones = pd.read_csv("/icgc/dkfzlsdf/analysis/B260/projects/przybilm/medulloblastoma/infercnv_MB/scRNA_scDNA/MB243-Nuclei/MB243-Nuclei_scDNA_clones_filtered_cells.txt", sep = '\t', index_col=0)
scDNA_clones
# Out:
#                    clone_id  pearson.correlation    Clone1    Clone2  \
# Cell_barcode
# AGGTCATTCAAGCCTA-1   Clone2             0.538949  0.000684  0.538949
# CTCGAAATCAAGGTAA-1   Clone3             0.530517 -0.003507  0.455145
# CACACAATCTGTCTCG-1   Clone3             0.578142 -0.006266  0.519190
# GGACATTTCCGTACAA-1   Clone3             0.531867  0.001968  0.484609
# ACAGCTAGTCTAAAGA-1   Clone2             0.515616  0.002570  0.515616
# ...                     ...                  ...       ...       ...
# TACGGATTCTATCCTA-1   Clone4             0.432330 -0.007630  0.428019
# AGGTCCGAGACTAGAT-1   Clone5             0.517202  0.005306  0.501647
# CGGAGTCTCCACGACG-1   Clone4             0.520406 -0.003760  0.514103
# CCGTACTCAGGCGATA-1   Clone2             0.432459  0.034874  0.432459
# CCTAGCTGTGCAACGA-1   Clone2             0.458565  0.032500  0.458565
#
#                       Clone3    Clone4    Clone5  Clone1_pval  Clone2_pval  \
# Cell_barcode
# AGGTCATTCAAGCCTA-1  0.501844  0.508322  0.518952        1.001        0.001
# CTCGAAATCAAGGTAA-1  0.530517  0.436133  0.420044        1.001        0.001
# CACACAATCTGTCTCG-1  0.578142  0.531083  0.514258        1.001        0.001
# GGACATTTCCGTACAA-1  0.531867  0.463018  0.444966        1.001        0.001
# ACAGCTAGTCTAAAGA-1  0.497955  0.504684  0.509022        1.001        0.001
# ...                      ...       ...       ...          ...          ...
# TACGGATTCTATCCTA-1  0.399951  0.432330  0.408143        1.001        0.001
# AGGTCCGAGACTAGAT-1  0.451137  0.514248  0.517202        1.001        0.001
# CGGAGTCTCCACGACG-1  0.430806  0.520406  0.517717        1.001        0.001
# CCGTACTCAGGCGATA-1  0.291152  0.354109  0.413408        1.001        0.001
# CCTAGCTGTGCAACGA-1  0.362216  0.402052  0.449555        1.001        0.001
#
#                     Clone3_pval  Clone4_pval  Clone5_pval  num_pval_clones  \
# Cell_barcode
# AGGTCATTCAAGCCTA-1        0.001        0.001        0.001                4
# CTCGAAATCAAGGTAA-1        0.001        0.001        0.085                3
# CACACAATCTGTCTCG-1        0.001        0.001        0.001                4
# GGACATTTCCGTACAA-1        0.001        0.001        0.009                3
# ACAGCTAGTCTAAAGA-1        0.001        0.001        0.001                4
# ...                         ...          ...          ...              ...
# TACGGATTCTATCCTA-1        0.001        0.001        0.001                4
# AGGTCCGAGACTAGAT-1        0.073        0.001        0.001                3
# CGGAGTCTCCACGACG-1        0.864        0.001        0.001                3
# CCGTACTCAGGCGATA-1        1.001        0.002        0.001                2
# CCTAGCTGTGCAACGA-1        0.871        0.001        0.001                3
#
#                     min_pval   padj
# Cell_barcode
# AGGTCATTCAAGCCTA-1     0.001  0.005
# CTCGAAATCAAGGTAA-1     0.001  0.005
# CACACAATCTGTCTCG-1     0.001  0.005
# GGACATTTCCGTACAA-1     0.001  0.005
# ACAGCTAGTCTAAAGA-1     0.001  0.005
# ...                      ...    ...
# TACGGATTCTATCCTA-1     0.001  0.005
# AGGTCCGAGACTAGAT-1     0.001  0.005
# CGGAGTCTCCACGACG-1     0.001  0.005
# CCGTACTCAGGCGATA-1     0.001  0.005
# CCTAGCTGTGCAACGA-1     0.001  0.005
#
# [6696 rows x 15 columns]

# %%
scDNA_clones = scDNA_clones.loc[scDNA_clones['padj'] <= 0.05, :]
scDNA_clones
# Out:
#                    clone_id  pearson.correlation    Clone1    Clone2  \
# Cell_barcode
# AGGTCATTCAAGCCTA-1   Clone2             0.538949  0.000684  0.538949
# CTCGAAATCAAGGTAA-1   Clone3             0.530517 -0.003507  0.455145
# CACACAATCTGTCTCG-1   Clone3             0.578142 -0.006266  0.519190
# GGACATTTCCGTACAA-1   Clone3             0.531867  0.001968  0.484609
# ACAGCTAGTCTAAAGA-1   Clone2             0.515616  0.002570  0.515616
# ...                     ...                  ...       ...       ...
# TACGGATTCTATCCTA-1   Clone4             0.432330 -0.007630  0.428019
# AGGTCCGAGACTAGAT-1   Clone5             0.517202  0.005306  0.501647
# CGGAGTCTCCACGACG-1   Clone4             0.520406 -0.003760  0.514103
# CCGTACTCAGGCGATA-1   Clone2             0.432459  0.034874  0.432459
# CCTAGCTGTGCAACGA-1   Clone2             0.458565  0.032500  0.458565
#
#                       Clone3    Clone4    Clone5  Clone1_pval  Clone2_pval  \
# Cell_barcode
# AGGTCATTCAAGCCTA-1  0.501844  0.508322  0.518952        1.001        0.001
# CTCGAAATCAAGGTAA-1  0.530517  0.436133  0.420044        1.001        0.001
# CACACAATCTGTCTCG-1  0.578142  0.531083  0.514258        1.001        0.001
# GGACATTTCCGTACAA-1  0.531867  0.463018  0.444966        1.001        0.001
# ACAGCTAGTCTAAAGA-1  0.497955  0.504684  0.509022        1.001        0.001
# ...                      ...       ...       ...          ...          ...
# TACGGATTCTATCCTA-1  0.399951  0.432330  0.408143        1.001        0.001
# AGGTCCGAGACTAGAT-1  0.451137  0.514248  0.517202        1.001        0.001
# CGGAGTCTCCACGACG-1  0.430806  0.520406  0.517717        1.001        0.001
# CCGTACTCAGGCGATA-1  0.291152  0.354109  0.413408        1.001        0.001
# CCTAGCTGTGCAACGA-1  0.362216  0.402052  0.449555        1.001        0.001
#
#                     Clone3_pval  Clone4_pval  Clone5_pval  num_pval_clones  \
# Cell_barcode
# AGGTCATTCAAGCCTA-1        0.001        0.001        0.001                4
# CTCGAAATCAAGGTAA-1        0.001        0.001        0.085                3
# CACACAATCTGTCTCG-1        0.001        0.001        0.001                4
# GGACATTTCCGTACAA-1        0.001        0.001        0.009                3
# ACAGCTAGTCTAAAGA-1        0.001        0.001        0.001                4
# ...                         ...          ...          ...              ...
# TACGGATTCTATCCTA-1        0.001        0.001        0.001                4
# AGGTCCGAGACTAGAT-1        0.073        0.001        0.001                3
# CGGAGTCTCCACGACG-1        0.864        0.001        0.001                3
# CCGTACTCAGGCGATA-1        1.001        0.002        0.001                2
# CCTAGCTGTGCAACGA-1        0.871        0.001        0.001                3
#
#                     min_pval   padj
# Cell_barcode
# AGGTCATTCAAGCCTA-1     0.001  0.005
# CTCGAAATCAAGGTAA-1     0.001  0.005
# CACACAATCTGTCTCG-1     0.001  0.005
# GGACATTTCCGTACAA-1     0.001  0.005
# ACAGCTAGTCTAAAGA-1     0.001  0.005
# ...                      ...    ...
# TACGGATTCTATCCTA-1     0.001  0.005
# AGGTCCGAGACTAGAT-1     0.001  0.005
# CGGAGTCTCCACGACG-1     0.001  0.005
# CCGTACTCAGGCGATA-1     0.001  0.005
# CCTAGCTGTGCAACGA-1     0.001  0.005
#
# [6696 rows x 15 columns]

# %%
adata.obs['clone_id'] = scDNA_clones['clone_id']
adata.obs['padj'] = scDNA_clones['padj']

# %%
adata.uns['clone_id_colors'] = np.array(["#E41A1C", "#377EB8", "#4DAF4A", "#984EA3", "#FF7F00", "#808080"])

# %%
sc.pl.umap(adata, color=['new_clusters', 'clone_id'], save = '_MB243-Nuclei_scDNA_clones_integrated.pdf', wspace = 0.5, legend_fontsize = 6)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'clone_id' as categorical
# WARNING: saving figure to file figures/umap_MB243-Nuclei_scDNA_clones_integrated.pdf

# %%
# assign the column with the cell_type id in the metadata of the annData object
metadata = pd.DataFrame(adata.obs, index=adata.obs_names)
metadata.to_csv('/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/infercnv_MB/MB243-Nuclei_metadata.csv')

# %%
# find marker genes for each cluster using the Wilcoxon rank sum test
sc.tl.rank_genes_groups(
            adata,
            groupby='clone_id',
            groups=["Clone1", 'Clone2', 'Clone3', 'Clone4', 'Clone5'],
            reference='rest',
            use_raw=True,
            method='wilcoxon',
            n_genes=2000,
            corr_method='benjamini-hochberg'
        )
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ranking genes
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:17)

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
wilcoxon_df = pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'logfoldchanges', 'scores',  "pvals", 'pvals_adj']})

# %%
wilcoxon_df.to_csv("/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/scanpy/MB243-Nuclei_DEG_wilcoxon_integrated_scDNA_clones_only.csv")

# %%
wilcoxon_df
# Out:
#       Clone1_n  Clone1_l  Clone1_s  Clone1_p Clone2_n  Clone2_l  Clone2_s  \
# 0      FAM213A  4.946233  2.921107       1.0    SEZ6L  0.300807  9.638474
# 1         NRG3  3.257853  2.918367       1.0    PTPRD  0.330452  9.203150
# 2      HSPA12A  5.076315  2.914806       1.0   SEMA6A  0.299386  7.864140
# 3        WAPAL  4.411586  2.876592       1.0      FTX  0.168874  7.804606
# 4     SLC16A10  4.390232  2.852212       1.0     NFIB  0.178130  7.741006
# ...        ...       ...       ...       ...      ...       ...       ...
# 1995    PRKAA1  1.182173  0.501301       1.0  ZC2HC1A  0.060562  0.872322
# 1996   C12orf4  1.505766  0.500890       1.0    CEP68  0.083877  0.871920
# 1997      KSR2  1.176059  0.500753       1.0     MSL1  0.083153  0.871778
# 1998  SLC25A53  1.159244  0.500616       1.0     DHPS  0.096123  0.871731
# 1999    ACTL6B  1.149818  0.498699       1.0    GREB1  0.076795  0.869899
#
#           Clone2_p      Clone3_n  Clone3_l   Clone3_s       Clone3_p  \
# 0     1.305247e-17         DACH2  1.821609  24.505533  3.060377e-128
# 1     4.124732e-16          NFIA  0.839449  19.790659   4.251875e-83
# 2     2.939931e-11       STXBP5L  1.024662  18.582550   3.519131e-73
# 3     3.541272e-11          PBX3  1.001350  18.379211   1.143599e-71
# 4     4.681526e-11         NLGN1  0.689627  17.887878   6.957407e-68
# ...            ...           ...       ...        ...            ...
# 1995  1.000000e+00          LMO4  0.152760   2.234891   2.721577e-01
# 1996  1.000000e+00         KDM6A  0.162992   2.234560   2.722681e-01
# 1997  1.000000e+00           NPS  0.995614   2.234221   2.723837e-01
# 1998  1.000000e+00  RP11-393I2.4  1.240084   2.232334   2.733455e-01
# 1999  1.000000e+00         DHX57  0.205016   2.232298   2.733455e-01
#
#          Clone4_n  Clone4_l  Clone4_s      Clone4_p       Clone5_n  Clone5_l  \
# 0            BAI3  0.483524  8.816642  2.799053e-14           GLI2  0.592188
# 1            NFIB  0.266271  8.644646  6.404377e-14         ZNF536  0.373564
# 2           PTPRD  0.460105  8.548965  9.824831e-14          DSCAM  0.296645
# 3         CNTNAP5  0.536166  8.469570  1.461296e-13           NAV2  0.361984
# 4           CNTN3  0.772441  8.417063  1.832312e-13           NRG3  0.391876
# ...           ...       ...       ...           ...            ...       ...
# 1995        EEF1D  0.104913  1.018468  1.000000e+00           TSKU  0.167706
# 1996     KIAA1549  0.122974  1.018121  1.000000e+00          SYNE4  0.402206
# 1997     ATP6AP1L  0.215522  1.017956  1.000000e+00           SYT8  0.202232
# 1998       BNIP3L  0.129233  1.017802  1.000000e+00          RBM4B  0.121141
# 1999  CTC-329D1.2  0.290460  1.017802  1.000000e+00  RP11-399J13.3  2.217729
#
#        Clone5_s      Clone5_p
# 0     15.306602  1.639381e-48
# 1     13.666577  1.907823e-38
# 2     10.147288  5.390292e-21
# 3      9.237535  2.137929e-17
# 4      8.496344  1.132515e-14
# ...         ...           ...
# 1995   0.250514  1.000000e+00
# 1996   0.250514  1.000000e+00
# 1997   0.250212  1.000000e+00
# 1998   0.250188  1.000000e+00
# 1999   0.250177  1.000000e+00
#
# [2000 rows x 20 columns]

# %%
# find marker genes for each cluster using the Wilcoxon rank sum test
sc.tl.rank_genes_groups(
            adata,
            groupby='clone_id',
            groups=["Clone1", 'Clone2', 'Clone3', 'Clone4', 'Clone5', 'nan'],
            reference="nan",
            use_raw=True,
            method='wilcoxon',
            n_genes=5000,
            corr_method='benjamini-hochberg'
        )
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
wilcoxon_df = pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'logfoldchanges', 'scores',  "pvals", 'pvals_adj']})

# %%
wilcoxon_df.to_csv("/omics/groups/OE0540/internal/projects/przybilm/medulloblastoma/revision/scrna_analysis/scanpy/MB243-Nuclei_DEG_wilcoxon_integrated_scDNA_clones_vs_normal_cells.csv")

# %%
sc.pl.umap(adata, color=['GLI2'], wspace = 0.5, save = '_MB243-Nuclei_GLI2_marker_visualization.pdf')
# Out:
# WARNING: saving figure to file figures/umap_MB243-Nuclei_GLI2_marker_visualization.pdf
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
sc.pl.umap(adata, color=['SETD2'], wspace = 0.5, save = '_MB243-Nuclei_SETD2_marker_visualization.pdf')
# Out:
# WARNING: saving figure to file figures/umap_MB243-Nuclei_SETD2_marker_visualization.pdf
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
# rcParams['figure.figsize'] = 4.5,3
sc.pl.violin(adata, ['GLI2'], groupby='sample', save = '_MB243-Nuclei_GLI2_marker_visualization.pdf')
# Out:
# WARNING: saving figure to file figures/violin_MB243-Nuclei_GLI2_marker_visualization.pdf
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %% [markdown]
# ## PROJECT CHROMOTRIPSIS SIGNATURE ONTO THE EMBEDDING

# %%
f="/icgc/dkfzlsdf/analysis/B260/projects/przybilm/medulloblastoma/scRNA_analysis/MB_shh_filtered_table_FDR.tsv"
pos_df=pd.read_table(f, sep='\t')
pos_df=pos_df.loc[pos_df['log2FoldChange'] > 0,:]
pos_df=pos_df.loc[pos_df['padj'] <= 0.05,:]
neg_df=pd.read_table(f, sep='\t')
neg_df=neg_df.loc[neg_df['log2FoldChange'] < 0,:]
neg_df=neg_df.loc[neg_df['padj'] <= 0.05,:]

# %%
pos_df
neg_df
# Out:
#                 ens_fullid           ens_id     baseMean  log2FoldChange  \
# 409   ENSG00000187097.12_3  ENSG00000187097  1662.242563       -0.359350
# 410    ENSG00000250462.8_2  ENSG00000250462  1332.612360       -0.407023
# 411   ENSG00000076242.14_2  ENSG00000076242  4657.937488       -0.414492
# 412   ENSG00000113812.13_3  ENSG00000113812  6868.479447       -0.436607
# 413   ENSG00000100890.15_3  ENSG00000100890   808.125224       -0.443807
# ...                    ...              ...          ...             ...
# 1042     ENSG00000237869.2  ENSG00000237869    12.804303       -5.767545
# 1043   ENSG00000183072.9_2  ENSG00000183072   260.545238       -5.943601
# 1044   ENSG00000266736.1_2  ENSG00000266736   102.835417       -6.129589
# 1045   ENSG00000253226.1_2  ENSG00000253226    23.377382       -6.273874
# 1046   ENSG00000232944.1_2  ENSG00000232944    21.826449       -7.265587
#
#          lfcSE      stat        pvalue      padj      gene_name
# 409   0.109875 -3.270523  1.073486e-03  0.036798         ENTPD5
# 410   0.128259 -3.173454  1.506366e-03  0.045176      LRRC37BP1
# 411   0.112141 -3.696177  2.188700e-04  0.013763           MLH1
# 412   0.127945 -3.412451  6.438160e-04  0.026346          ACTR8
# 413   0.140809 -3.151842  1.622438e-03  0.047158       KIAA0391
# ...        ...       ...           ...       ...            ...
# 1042  1.786001 -3.229307  1.240907e-03  0.040182  RP11-459O16.1
# 1043  1.123514 -5.290188  1.220000e-07  0.000112         NKX2-5
# 1044  1.766502 -3.469902  5.206490e-04  0.023260   RP11-260A9.4
# 1045  1.701660 -3.686913  2.269910e-04  0.014047        HAUS1P3
# 1046  1.786441 -4.067074  4.760000e-05  0.005446  RP13-492C18.1
#
# [638 rows x 9 columns]

# %%
gene_list_pos=pos_df['gene_name']
intersect_gene_list_pos=adata.var_names.isin(list(gene_list_pos))
gene_list_pos=adata.var_names[intersect_gene_list_pos]

# %%
len(gene_list_pos)
# Out:
# 45

# %%
gene_list_neg=neg_df['gene_name']
intersect_gene_list_neg=adata.var_names.isin(list(gene_list_neg))
gene_list_neg=adata.var_names[intersect_gene_list_neg]

# %%
len(gene_list_neg)
# Out:
# 200

# %%
sc.tl.score_genes(adata, list(gene_list_pos), ctrl_size=len(gene_list_pos), gene_pool=None, n_bins=25, score_name='Upregulated_Chromothripsis_Score', random_state=0, copy=False, use_raw=None)
sc.tl.score_genes(adata, list(gene_list_neg), ctrl_size=len(gene_list_neg), gene_pool=None, n_bins=25, score_name='Downregulated_Chromothripsis_Score', random_state=0, copy=False, use_raw=None)
# Out:
# computing score 'Upregulated_Chromothripsis_Score'
#     finished: added
#     'Upregulated_Chromothripsis_Score', score of gene set (adata.obs).
#     796 total control genes are used. (0:00:00)
# computing score 'Downregulated_Chromothripsis_Score'
#     finished: added
#     'Downregulated_Chromothripsis_Score', score of gene set (adata.obs).
#     2857 total control genes are used. (0:00:00)

# %%
sc.pl.umap(adata, color=['Upregulated_Chromothripsis_Score', 'Downregulated_Chromothripsis_Score'], save = '_MB243-Nuclei_chromothripsisScore.pdf', wspace = 0.5)
# Out:
# /home/przybilm/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# WARNING: saving figure to file figures/umap_MB243-Nuclei_chromothripsisScore.pdf

# %%
# assign the column with the cell_type id in the metadata of the annData object
metadata = pd.DataFrame(adata.obs, index=adata.obs_names)
metadata.to_csv('/icgc/dkfzlsdf/analysis/B260/projects/przybilm/medulloblastoma/infercnv_MB/scRNA_scDNA/MB243-Nuclei_chromothripsisScore_metadata.csv')

# %%
metadata
# Out:
#                    sample technology patient  scrublet__predicted_multiplet  \
# AAACCTGAGAAACCGC-1  MB243     Nuclei   MB243                          False
# AAACCTGAGAACAATC-1  MB243     Nuclei   MB243                          False
# AAACCTGAGCACCGTC-1  MB243     Nuclei   MB243                          False
# AAACCTGAGCAGCGTA-1  MB243     Nuclei   MB243                          False
# AAACCTGAGGAATTAC-1  MB243     Nuclei   MB243                          False
# ...                   ...        ...     ...                            ...
# TTTGTCAGTTCCTCCA-1  MB243     Nuclei   MB243                          False
# TTTGTCATCAATCACG-1  MB243     Nuclei   MB243                          False
# TTTGTCATCCCAACGG-1  MB243     Nuclei   MB243                          False
# TTTGTCATCGCTTGTC-1  MB243     Nuclei   MB243                          False
# TTTGTCATCTATGTGG-1  MB243     Nuclei   MB243                          False
#
#                     scrublet__multiplet_scores  scrublet__multiplet_zscores  \
# AAACCTGAGAAACCGC-1                    0.034719                   -27.183376
# AAACCTGAGAACAATC-1                    0.099617                    -7.996945
# AAACCTGAGCACCGTC-1                    0.077209                   -11.017576
# AAACCTGAGCAGCGTA-1                    0.065341                   -13.444356
# AAACCTGAGGAATTAC-1                    0.052458                   -17.300773
# ...                                        ...                          ...
# TTTGTCAGTTCCTCCA-1                    0.038988                   -24.000467
# TTTGTCATCAATCACG-1                    0.072134                   -11.958865
# TTTGTCATCCCAACGG-1                    0.103584                    -7.596906
# TTTGTCATCGCTTGTC-1                    0.065341                   -13.444356
# TTTGTCATCTATGTGG-1                    0.085812                    -9.673434
#
#                     n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCTGAGAAACCGC-1     1606               1606        2524.0              3.0
# AAACCTGAGAACAATC-1     3564               3563        7115.0             15.0
# AAACCTGAGCACCGTC-1     3218               3215        5837.0              5.0
# AAACCTGAGCAGCGTA-1     2974               2974        5423.0              2.0
# AAACCTGAGGAATTAC-1     4180               4179        8695.0             11.0
# ...                     ...                ...           ...              ...
# TTTGTCAGTTCCTCCA-1     2020               2019        3161.0              2.0
# TTTGTCATCAATCACG-1     3786               3785        7858.0              5.0
# TTTGTCATCCCAACGG-1     2499               2499        4407.0              5.0
# TTTGTCATCGCTTGTC-1      924                924        1126.0              2.0
# TTTGTCATCTATGTGG-1     2997               2997        5907.0              9.0
#
#                     ...  total_counts_ribo  pct_counts_ribo  louvain  \
# AAACCTGAGAAACCGC-1  ...               12.0         0.475436        5
# AAACCTGAGAACAATC-1  ...               42.0         0.590302        0
# AAACCTGAGCACCGTC-1  ...               32.0         0.548227        4
# AAACCTGAGCAGCGTA-1  ...               31.0         0.571639        0
# AAACCTGAGGAATTAC-1  ...               60.0         0.690052        4
# ...                 ...                ...              ...      ...
# TTTGTCAGTTCCTCCA-1  ...               27.0         0.854160        0
# TTTGTCATCAATCACG-1  ...               40.0         0.509035        4
# TTTGTCATCCCAACGG-1  ...               28.0         0.635353        1
# TTTGTCATCGCTTGTC-1  ...               10.0         0.888099        2
# TTTGTCATCTATGTGG-1  ...               17.0         0.287794        4
#
#                       leiden                    new_clusters clone_id  \
# AAACCTGAGAAACCGC-1  cluster1  malignant neuronal development   Clone3
# AAACCTGAGAACAATC-1  cluster0           malignant basal state   Clone2
# AAACCTGAGCACCGTC-1  cluster3               malignant cycling   Clone2
# AAACCTGAGCAGCGTA-1  cluster0           malignant basal state   Clone5
# AAACCTGAGGAATTAC-1  cluster3               malignant cycling   Clone2
# ...                      ...                             ...      ...
# TTTGTCAGTTCCTCCA-1  cluster0           malignant basal state   Clone2
# TTTGTCATCAATCACG-1  cluster3               malignant cycling   Clone2
# TTTGTCATCCCAACGG-1  cluster1  malignant neuronal development   Clone5
# TTTGTCATCGCTTGTC-1  cluster0           malignant basal state   Clone2
# TTTGTCATCTATGTGG-1  cluster3               malignant cycling   Clone2
#
#                    min_pval  chromothripsis_score  \
# AAACCTGAGAAACCGC-1    0.001              0.001838
# AAACCTGAGAACAATC-1    0.001              0.049266
# AAACCTGAGCACCGTC-1    0.001              0.090227
# AAACCTGAGCAGCGTA-1    0.001              0.030149
# AAACCTGAGGAATTAC-1    0.001             -0.066851
# ...                     ...                   ...
# TTTGTCAGTTCCTCCA-1    0.001             -0.030556
# TTTGTCATCAATCACG-1    0.001              0.076236
# TTTGTCATCCCAACGG-1    0.001              0.032217
# TTTGTCATCGCTTGTC-1    0.001              0.197624
# TTTGTCATCTATGTGG-1    0.001              0.077912
#
#                     Upregulated_Chromothripsis_Score  \
# AAACCTGAGAAACCGC-1                          0.001838
# AAACCTGAGAACAATC-1                          0.049266
# AAACCTGAGCACCGTC-1                          0.090227
# AAACCTGAGCAGCGTA-1                          0.030149
# AAACCTGAGGAATTAC-1                         -0.066851
# ...                                              ...
# TTTGTCAGTTCCTCCA-1                         -0.030556
# TTTGTCATCAATCACG-1                          0.076236
# TTTGTCATCCCAACGG-1                          0.032217
# TTTGTCATCGCTTGTC-1                          0.197624
# TTTGTCATCTATGTGG-1                          0.077912
#
#                     Downregulated_Chromothripsis_Score
# AAACCTGAGAAACCGC-1                           -0.120067
# AAACCTGAGAACAATC-1                           -0.133942
# AAACCTGAGCACCGTC-1                           -0.137896
# AAACCTGAGCAGCGTA-1                           -0.094151
# AAACCTGAGGAATTAC-1                           -0.112462
# ...                                                ...
# TTTGTCAGTTCCTCCA-1                           -0.108897
# TTTGTCATCAATCACG-1                           -0.090186
# TTTGTCATCCCAACGG-1                           -0.126545
# TTTGTCATCGCTTGTC-1                           -0.076729
# TTTGTCATCTATGTGG-1                           -0.103314
#
# [7302 rows x 21 columns]

# %%
data_crosstab = pd.crosstab(metadata['new_clusters'], metadata['clone_id'], margins = False)
print(data_crosstab)
# Out:
# clone_id                        Clone1  Clone2  Clone3  Clone4  Clone5  nan
# new_clusters
# malignant basal state                0    1169      82     257    1548       0
# malignant neuronal development       2     676     426     281     350       0
# malignant SHH                        0     300     535      56     145       0
# malignant cycling                    1     254     207      70     337       0
# macrophages                          0       0       0       0       0     224
# astrocytes                           0       0       0       0       0     183
# meninge cells                        0       0       0       0       0     165
# endothelial cells                    0       0       0       0       0      34

# %%
data_crosstab.to_csv('/icgc/dkfzlsdf/analysis/B260/projects/przybilm/medulloblastoma/infercnv_MB/scRNA_scDNA/MB243-Nuclei_contingencyTable_celltypes_clones.csv')
